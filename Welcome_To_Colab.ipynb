# %% [markdown]
# <a href="https://colab.research.google.com/github/AHRMA/developing_a_func_from-zero/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Data Structures

# %%
my_list= [1,2,3]

# %%
type(my_list)
# Out:
# list

# %%
my_list[0]
# Out:
# 1

# %% [markdown]
# # New Section
